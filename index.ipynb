# %%
import pandas as pd

# %%
df = pd.read_csv('causes_of_death.tsv', delimiter='\t')
print(len(df))
df.sample(10)
# Out:
# 4115
#       Notes                 State  State Code Ten-Year Age Groups  \
# 612     NaN              Delaware          10          5-14 years
# 4029    NaN             Wisconsin          55         65-74 years
# 2554    NaN            New Mexico          35         35-44 years
# 1077    NaN              Illinois          17         15-24 years
# 707     NaN  District of Columbia          11         55-64 years
# 1278    NaN                  Iowa          19         55-64 years
# 343     NaN            California           6            < 1 year
# 2006    NaN           Mississippi          28         45-54 years
# 2956    NaN              Oklahoma          40          5-14 years
# 1108    NaN              Illinois          17         55-64 years
#
#      Ten-Year Age Groups Code  Gender Gender Code  \
# 612                      5-14    Male           M
# 4029                    65-74    Male           M
# 2554                    35-44  Female           F
# 1077                    15-24  Female           F
# 707                     55-64    Male           M
# 1278                    55-64    Male           M
# 343                         1    Male           M
# 2006                    45-54  Female           F
# 2956                     5-14    Male           M
# 1108                    55-64  Female           F
#
#                                   Race Race Code  Deaths Population Crude Rate
# 612                              White    2106-3     108     696840       15.5
# 4029         Asian or Pacific Islander      A-PI     400      28569     1400.1
# 2554  American Indian or Alaska Native    1002-5     739     255843      288.8
# 1077         Asian or Pacific Islander      A-PI     123     751437       16.4
# 707          Black or African American    2054-5    7039     294629     2389.1
# 1278  American Indian or Alaska Native    1002-5      84       7814     1075.0
# 343                              White    2106-3   19597    3641682      538.1
# 2006         Asian or Pacific Islander      A-PI      70      35683      196.2
# 2956         Black or African American    2054-5     154     514938       29.9
# 1108  American Indian or Alaska Native    1002-5     111      45363      244.7

# %% [markdown]
# # Practice Explorations

# %% [markdown]
# ### Groupby State and Sum the numeric features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4115 entries, 0 to 4114
# Data columns (total 12 columns):
# Notes                       0 non-null float64
# State                       4115 non-null object
# State Code                  4115 non-null int64
# Ten-Year Age Groups         4115 non-null object
# Ten-Year Age Groups Code    4115 non-null object
# Gender                      4115 non-null object
# Gender Code                 4115 non-null object
# Race                        4115 non-null object
# Race Code                   4115 non-null object
# Deaths                      4115 non-null int64
# Population                  4115 non-null object
# Crude Rate                  4115 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 385.9+ KB

# %%
grouped1 = df.groupby('State')[['Deaths', '']].sum()
grouped1.head(10)
# Out:
#                        Deaths
# State
# Alabama                860780
# Alaska                  63334
# Arizona                838094
# Arkansas               522914
# California            4307061
# Colorado               561283
# Connecticut            531290
# Delaware               135933
# District of Columbia    94073
# Florida               3131111

# %% [markdown]
# ### Calculate the Correlation Coefficient between the Deaths and Population Columns (of your grouped dataframe)

# %%
#Your code here

# %% [markdown]
# ### Repeat this process across multiple features
# Iterate over the following columns: ['Race', 'Gender', 'Ten-Year Age Groups']. Within your for loop, create a temporary groupby aggregate as we did for the State column above. Then, print any aggregate grouping where the correlation coefficient is less then .95.

# %%
#Your code here

# %% [markdown]
# ### Combining Features
#
# We can further expand upon our exploration above by testing multiple features against each other!
# Complete the code below to print any combination of features where the correlation between population and death is below .95 (or some other appropriate threshold).

# %%
#This could also be accomplished with the combinations() method from the itertools package.
for n, feat1 in enumerate(features):
    for feat2 in features[n:]:
        #Your code here
        #groupby feat1 and feat2!!
        #repeat your code above to check if the correlation is below a [high] threshold.
