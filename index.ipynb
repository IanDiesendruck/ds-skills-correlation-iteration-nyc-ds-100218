# %%
import pandas as pd

# %%
df = pd.read_csv('causes_of_death.tsv', delimiter='\t')
print(len(df))
df.head(80)
# Out:
# 4115
#     Notes    State  State Code Ten-Year Age Groups Ten-Year Age Groups Code  \
# 0     NaN  Alabama           1            < 1 year                        1
# 1     NaN  Alabama           1            < 1 year                        1
# 2     NaN  Alabama           1            < 1 year                        1
# 3     NaN  Alabama           1            < 1 year                        1
# 4     NaN  Alabama           1            < 1 year                        1
# ..    ...      ...         ...                 ...                      ...
# 75    NaN  Alabama           1           85+ years                      85+
# 76    NaN  Alabama           1           85+ years                      85+
# 77    NaN  Alabama           1           85+ years                      85+
# 78    NaN  Alabama           1           85+ years                      85+
# 79    NaN  Alabama           1           85+ years                      85+
#
#     Gender Gender Code                              Race Race Code  Deaths  \
# 0   Female           F  American Indian or Alaska Native    1002-5      14
# 1   Female           F         Asian or Pacific Islander      A-PI      24
# 2   Female           F         Black or African American    2054-5    2093
# 3   Female           F                             White    2106-3    2144
# 4     Male           M         Asian or Pacific Islander      A-PI      33
# ..     ...         ...                               ...       ...     ...
# 75  Female           F                             White    2106-3  116297
# 76    Male           M  American Indian or Alaska Native    1002-5      40
# 77    Male           M         Asian or Pacific Islander      A-PI      92
# 78    Male           M         Black or African American    2054-5   12016
# 79    Male           M                             White    2106-3   57514
#
#    Population  Crude Rate
# 0        3579  Unreliable
# 1        7443       322.5
# 2      169339      1236.0
# 3      347921       616.2
# 4        7366       448.0
# ..        ...         ...
# 75     740184     15711.9
# 76       1129      3543.0
# 77       1269      7249.8
# 78      68421     17561.9
# 79     320674     17935.3
#
# [80 rows x 12 columns]

# %% [markdown]
# # Practice Explorations

# %% [markdown]
# ### Groupby State and Sum the numeric features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4115 entries, 0 to 4114
# Data columns (total 12 columns):
# Notes                       0 non-null float64
# State                       4115 non-null object
# State Code                  4115 non-null int64
# Ten-Year Age Groups         4115 non-null object
# Ten-Year Age Groups Code    4115 non-null object
# Gender                      4115 non-null object
# Gender Code                 4115 non-null object
# Race                        4115 non-null object
# Race Code                   4115 non-null object
# Deaths                      4115 non-null int64
# Population                  4115 non-null object
# Crude Rate                  4115 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 385.9+ KB

# %%
df['Population'] = pd.to_numeric(df['Population'])
# Out:
# ValueErrorTraceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Not Applicable"
#
# During handling of the above exception, another exception occurred:
#
# ValueErrorTraceback (most recent call last)
# <ipython-input-21-6cff8b7381bb> in <module>
# ----> 1 df['Population'] = pd.to_numeric(df['Population'])
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     149             coerce_numeric = errors not in ("ignore", "raise")
#     150             values = lib.maybe_convert_numeric(
# --> 151                 values, set(), coerce_numeric=coerce_numeric
#     152             )
#     153
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Not Applicable" at position 80

# %%
grouped1 = df.groupby('State')[['Deaths', 'State Code']].sum()
grouped1.head(10)
# Out:
#                        Deaths  State Code
# State
# Alabama                860780          81
# Alaska                  63334         164
# Arizona                838094         368
# Arkansas               522914         405
# California            4307061         564
# Colorado               561283         704
# Connecticut            531290         729
# Delaware               135933         690
# District of Columbia    94073         715
# Florida               3131111        1080

# %% [markdown]
# ### Calculate the Correlation Coefficient between the Deaths and Population Columns (of your grouped dataframe)

# %%
#Your code here

# %% [markdown]
# ### Repeat this process across multiple features
# Iterate over the following columns: ['Race', 'Gender', 'Ten-Year Age Groups']. Within your for loop, create a temporary groupby aggregate as we did for the State column above. Then, print any aggregate grouping where the correlation coefficient is less then .95.

# %%
#Your code here

# %% [markdown]
# ### Combining Features
#
# We can further expand upon our exploration above by testing multiple features against each other!
# Complete the code below to print any combination of features where the correlation between population and death is below .95 (or some other appropriate threshold).

# %%
#This could also be accomplished with the combinations() method from the itertools package.
for n, feat1 in enumerate(features):
    for feat2 in features[n:]:
        #Your code here
        #groupby feat1 and feat2!!
        #repeat your code above to check if the correlation is below a [high] threshold.
